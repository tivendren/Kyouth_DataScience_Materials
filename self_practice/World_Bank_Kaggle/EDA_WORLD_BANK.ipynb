# %% [markdown]
# In this lab,I'm going to use pandas to explore the World Bank's data on economic, political, and social indicators for countries around the world. The data is collected from Kaggle[https://www.kaggle.com/datasets/rishidamarla/world-bank-data].
#
# The World Bank data is organized into a number of different categories, including:
#
# Economy: This category includes data on GDP, population, inflation, and unemployment.
# Government: This category includes data on government spending, taxes, and debt.
# Social: This category includes data on education, health, and poverty.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bank_df=pd.read_excel("../World_Bank_Kaggle/2015 World Bank data by nation and region.xls")

# %%
bank_df.head()
# Out:
#   Country Name Region Code Country Code  GDP, PPP (current international $)  \
# 0        Aruba          MA          ABW                                 NaN
# 1      Andorra          EU          AND                                 NaN
# 2  Afghanistan          ME          AFG                        6.291267e+10
# 3       Angola          AF          AGO                        1.844377e+11
# 4      Albania          EU          ALB                        3.266324e+10
#
#    Population, total  Population CGR 1960-2015  \
# 0           103889.0                  0.011897
# 1            70473.0                  0.030622
# 2         32526562.0                  0.023646
# 3         25021974.0                  0.028724
# 4          2889167.0                  0.010702
#
#    Internet users (per 100 people)  Popltn Largest City % of Urban Pop  \
# 0                        88.661227                                 NaN
# 1                        96.910000                                 NaN
# ...

# %%
bank_df.tail()
# Out:
#          Country Name Region Code Country Code  \
# 259       Yemen, Rep.          ME          YEM
# 260      South Africa          AF          ZAF
# 261  Congo, Dem. Rep.          AF          COD
# 262            Zambia          AF          ZMB
# 263          Zimbabwe          AF          ZWE
#
#      GDP, PPP (current international $)  Population, total  \
# 259                                 NaN         26832215.0
# 260                        7.235160e+11         54956920.0
# 261                        6.048226e+10         77266814.0
# 262                        6.245841e+10         16211767.0
# 263                        2.798488e+10         15602751.0
#
#      Population CGR 1960-2015  Internet users (per 100 people)  \
# 259                  0.030407                        25.099514
# 260                  0.021135                        51.919116
# 261                  0.029945                         3.800000
# 262                  0.030843                        21.000000
# ...

# %%
bank_df.columns
# Out:
# Index(['Country Name', 'Region Code', 'Country Code',
#        'GDP, PPP (current international $)', 'Population, total',
#        'Population CGR 1960-2015', 'Internet users (per 100 people)',
#        'Popltn Largest City % of Urban Pop',
#        '2014 Life expectancy at birth, total (years)',
#        'Literacy rate, adult female (% of females ages 15 and above)',
#        'Exports of goods and services (% of GDP)'],
#       dtype='object')

# %%
bank_df.shape
# Out:
# (264, 11)

# %%
bank_df.dtypes
# Out:
# Country Name                                                     object
# Region Code                                                      object
# Country Code                                                     object
# GDP, PPP (current international $)                              float64
# Population, total                                               float64
# Population CGR 1960-2015                                        float64
# Internet users (per 100 people)                                 float64
# Popltn Largest City % of Urban Pop                              float64
# 2014 Life expectancy at birth, total (years)                    float64
# Literacy rate, adult female (% of females ages 15 and above)    float64
# Exports of goods and services (% of GDP)                        float64
# dtype: object

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 11 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country Name                                                  264 non-null    object
#  1   Region Code                                                   210 non-null    object
#  2   Country Code                                                  264 non-null    object
#  3   GDP, PPP (current international $)                            214 non-null    float64
#  4   Population, total                                             262 non-null    float64
#  5   Population CGR 1960-2015                                      258 non-null    float64
#  6   Internet users (per 100 people)                               248 non-null    float64
# ...

# %%
bank_df.describe()
# Out:
#        GDP, PPP (current international $)  Population, total  \
# count                        2.140000e+02       2.620000e+02
# mean                         4.758335e+12       2.970610e+08
# std                          1.370365e+13       9.376648e+08
# min                          2.089545e+08       9.916000e+03
# 25%                          3.015109e+10       1.464251e+06
# 50%                          1.679587e+11       1.009667e+07
# 75%                          1.584579e+12       5.469198e+07
# max                          1.136535e+14       7.346633e+09
#
#        Population CGR 1960-2015  Internet users (per 100 people)  \
# count                258.000000                       248.000000
# mean                   0.018255                        47.556571
# std                    0.011218                        27.691717
# min                   -0.001666                         1.083733
# 25%                    0.009471                        21.932051
# ...

# %% [markdown]
# ## Finding the null values

# %%
bank_df.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                      54
# Country Code                                                      0
# GDP, PPP (current international $)                               50
# Population, total                                                 2
# Population CGR 1960-2015                                          6
# Internet users (per 100 people)                                  16
# Popltn Largest City % of Urban Pop                               72
# 2014 Life expectancy at birth, total (years)                     19
# Literacy rate, adult female (% of females ages 15 and above)    108
# Exports of goods and services (% of GDP)                         84
# dtype: int64

# %%
null_df=pd.DataFrame(bank_df.isnull().sum(),columns=["Count of Nulls"])
null_df.sort_values(by="Count of Nulls",ascending=True)
# Out:
#                                                     Count of Nulls
# Country Name                                                     0
# Country Code                                                     0
# Population, total                                                2
# Population CGR 1960-2015                                         6
# Internet users (per 100 people)                                 16
# 2014 Life expectancy at birth, total (years)                    19
# GDP, PPP (current international $)                              50
# Region Code                                                     54
# Popltn Largest City % of Urban Pop                              72
# Exports of goods and services (% of GDP)                        84
# Literacy rate, adult female (% of females ages ...             108

# %%
bank_df[bank_df["Population, total"].isnull()==True]
# Out:
#        Country Name Region Code Country Code  \
# 66          Eritrea          AF          ERI
# 107  Not classified         NaN          INX
#
#      GDP, PPP (current international $)  Population, total  \
# 66                                  NaN                NaN
# 107                                 NaN                NaN
#
#      Population CGR 1960-2015  Internet users (per 100 people)  \
# 66                        NaN                         1.083733
# 107                       NaN                              NaN
#
#      Popltn Largest City % of Urban Pop  \
# 66                                  NaN
# 107                                 NaN
#
#      2014 Life expectancy at birth, total (years)  \
# 66                                      63.663024
# 107                                           NaN
#
#      Literacy rate, adult female (% of females ages 15 and above)  \
# 66                                           65.608772
# ...

# %%
bank_df[bank_df["Region Code"].isnull()==True]
# Out:
#                                           Country Name Region Code  \
# 5                                           Arab World         NaN
# 25                                             Bermuda         NaN
# 33                                              Canada         NaN
# 34                      Central Europe and the Baltics         NaN
# 46                              Caribbean small states         NaN
# 58         East Asia & Pacific (excluding high income)         NaN
# 59                          Early-demographic dividend         NaN
# 60                                 East Asia & Pacific         NaN
# 61       Europe & Central Asia (excluding high income)         NaN
# 62                               Europe & Central Asia         NaN
# 65                                           Euro area         NaN
# 70                                      European Union         NaN
# 71            Fragile and conflict affected situations         NaN
# ...

# %% [markdown]
# ## Dropping the rows which doesn't have total population

# %%
bank_df.dropna(subset=["Population, total"],axis=0,inplace=True)

# %%
bank_df.isnull().sum()
# Out:
# Country Name                                                      0
# Region Code                                                      53
# Country Code                                                      0
# GDP, PPP (current international $)                               48
# Population, total                                                 0
# Population CGR 1960-2015                                          4
# Internet users (per 100 people)                                  15
# Popltn Largest City % of Urban Pop                               70
# 2014 Life expectancy at birth, total (years)                     18
# Literacy rate, adult female (% of females ages 15 and above)    107
# Exports of goods and services (% of GDP)                         82
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bank_df["Country Name"].apply(lambda x: x[0:3])
# Out:
# 0      Aru
# 1      And
# 2      Afg
# 3      Ang
# 4      Alb
#       ...
# 259    Yem
# 260    Sou
# 261    Con
# 262    Zam
# 263    Zim
# Name: Country Name, Length: 262, dtype: object

# %%
bank_df.fillna(value={"Region Code":bank_df["Country Name"].apply(lambda x: x[0:2].upper()),
                      "GDP, PPP (current international $)":bank_df["GDP, PPP (current international $)"].mean(),
                      "Population CGR 1960-2015" : ( bank_df["Population, total"]/ (0.6 * (bank_df["Population, total"]) )**(1/4))-1,
                      "Internet users (per 100 people)": (bank_df["Population, total"]*((0.8+0.5+0.6)/3)),
                      "Popltn Largest City % of Urban Pop" : 0.3*bank_df["Population, total"],
                      "2014 Life expectancy at birth, total (years)": bank_df["2014 Life expectancy at birth, total (years)"].mean(),
                      "Literacy rate, adult female (% of females ages 15 and above)":bank_df["Literacy rate, adult female (% of females ages 15 and above)"].mean(),
                      "Exports of goods and services (% of GDP)":bank_df["Exports of goods and services (% of GDP)"].mean()
                     }).head(10)
# Out:
#            Country Name Region Code Country Code  \
# 0                 Aruba          MA          ABW
# 1               Andorra          EU          AND
# 2           Afghanistan          ME          AFG
# 3                Angola          AF          AGO
# 4               Albania          EU          ALB
# 5            Arab World          AR          ARB
# 6  United Arab Emirates          ME          ARE
# 7             Argentina          SA          ARG
# 8               Armenia          RU          ARM
# 9        American Samoa          PA          ASM
#
#    GDP, PPP (current international $)  Population, total  \
# 0                        4.758335e+12           103889.0
# 1                        4.758335e+12            70473.0
# 2                        6.291267e+10         32526562.0
# 3                        1.844377e+11         25021974.0
# 4                        3.266324e+10          2889167.0
# 5                        6.435292e+12        392022276.0
# ...

# %%
copy_bank_df=bank_df.copy()


bank_df.fillna(value={"Region Code":bank_df["Country Name"].apply(lambda x: x[0:2].upper()),
                      "GDP, PPP (current international $)":bank_df["GDP, PPP (current international $)"].mean(),
                      "Population CGR 1960-2015" : ( bank_df["Population, total"]/ (0.6 * (bank_df["Population, total"]) )**(1/4))-1,
                      "Internet users (per 100 people)": (bank_df["Population, total"]*((0.8+0.5+0.6)/3)),
                      "Popltn Largest City % of Urban Pop" : 0.3*bank_df["Population, total"],
                      "2014 Life expectancy at birth, total (years)": bank_df["2014 Life expectancy at birth, total (years)"].mean(),
                      "Literacy rate, adult female (% of females ages 15 and above)":bank_df["Literacy rate, adult female (% of females ages 15 and above)"].mean(),
                      "Exports of goods and services (% of GDP)":bank_df["Exports of goods and services (% of GDP)"].mean()
                     },
              inplace=True)

bank_df.isnull().sum()
# Out:
# Country Name                                                    0
# Region Code                                                     0
# Country Code                                                    0
# GDP, PPP (current international $)                              0
# Population, total                                               0
# Population CGR 1960-2015                                        0
# Internet users (per 100 people)                                 0
# Popltn Largest City % of Urban Pop                              0
# 2014 Life expectancy at birth, total (years)                    0
# Literacy rate, adult female (% of females ages 15 and above)    0
# Exports of goods and services (% of GDP)                        0
# dtype: int64
